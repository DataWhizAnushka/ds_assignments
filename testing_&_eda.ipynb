# %% [markdown]
# <a href="https://colab.research.google.com/github/DataWhizAnushka/ds_assignments/blob/main/testing_%26_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CHI-SQUARE TEST**

# %% [markdown]
# Objective:
# To use the Chi-Square test for independence to determine if there's a significant association between the type of smart home device purchased (Smart Thermostats vs. Smart Lights) and the customer satisfaction level.

# %% [markdown]
# 1. State the Hypotheses:

# %%
# Null Hypothesis (H0): There is no association between device type and customer satisfaction level.
# Alternative Hypothesis (H1): There is an association between device type and customer satisfaction level.

# %% [markdown]
# 2. Compute the Chi-Square Statistic:

# %%
import scipy.stats as stats

# %%
observed = [[50, 70],
            [80, 100],
            [60, 90],
            [30, 50],
            [20, 50]]

# %% [markdown]
# 3. Determine the Critical Value:
# Using the significance level (alpha) of 0.05 and the degrees of freedom (which is the number of categories minus 1)

# %%
stats.chi2.ppf(1 - alpha, dof)
# Out:
# 9.487729036781154

# %% [markdown]
# 4. Make a Decision:
# Compare the Chi-Square statistic with the critical value to decide whether to reject the null hypothesis.

# %%
if chi2_stat > critical_value:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

# %% [markdown]
# Submission Guidelines:

# %%
print("Step 1: State the Hypotheses:")
print("Null Hypothesis (H0): There is no association between device type and customer satisfaction level.")
print("Alternative Hypothesis (H1): There is an association between device type and customer satisfaction level.")
print("\nStep 2: Compute the Chi-Square Statistic:")
print("Chi-Square Statistic:", chi2_stat)
print("\nStep 3: Determine the Critical Value:")
print("Critical Value:", critical_value)
print("\nStep 4: Make a Decision:")
print("Decision:", decision)
# Out:
# Step 1: State the Hypotheses:
# Null Hypothesis (H0): There is no association between device type and customer satisfaction level.
# Alternative Hypothesis (H1): There is an association between device type and customer satisfaction level.
#
# Step 2: Compute the Chi-Square Statistic:
# Chi-Square Statistic: 5.638227513227513
#
# Step 3: Determine the Critical Value:
# Critical Value: 9.487729036781154
#
# Step 4: Make a Decision:
# Decision: Fail to reject the null hypothesis

# %% [markdown]
# **HYPOTHESIS TESTING**

# %% [markdown]
# Objective:
# To investigate the restaurant owners' claim about the increase in weekly operating costs using hypothesis testing.

# %% [markdown]
# 1. State the Hypotheses statement:

# %%
# Null Hypothesis (H0): The mean weekly operating cost according to the theoretical model is accurate.
# Alternative Hypothesis (H1): The mean weekly operating cost is higher than the theoretical model suggests.

# %% [markdown]
# 2. Calculate the Test Statistic:

# %%
sample_mean = 3050
theoretical_mean = 1000 + 5 * 600
population_std = 5 * 25
n = 25

# %% [markdown]
# 3. Determine the Critical Value:

# %%
 (sample_mean - theoretical_mean) / (population_std / (n ** 0.5))
# Out:
# -38.0

# %% [markdown]
# 4. Make a Decision:

# %%
if t_statistic > critical_value:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

# %% [markdown]
# 5. Conclusion:

# %%
if t_statistic > critical_value:
    conclusion = "There is strong evidence to support the restaurant owners' claim that the weekly operating costs are higher than the model suggests."
else:
    conclusion = "There is not enough evidence to support the restaurant owners' claim that the weekly operating costs are higher than the model suggests."

# %% [markdown]
# Submission Guidelines:

# %%
print("Step 1: State the Hypotheses:")
print("Null Hypothesis (H0): The mean weekly operating cost according to the theoretical model is accurate.")
print("Alternative Hypothesis (H1): The mean weekly operating cost is higher than the theoretical model suggests.")
print("\nStep 2: Calculate the Test Statistic:")
print("Test Statistic (t):", t_statistic)
print("\nStep 3: Determine the Critical Value:")
print("Critical Value:", critical_value)
print("\nStep 4: Make a Decision:")
print("Decision:", decision)
print("\nStep 5: Conclusion:")
print("Conclusion:", conclusion)
# Out:
# Step 1: State the Hypotheses:
# Null Hypothesis (H0): The mean weekly operating cost according to the theoretical model is accurate.
# Alternative Hypothesis (H1): The mean weekly operating cost is higher than the theoretical model suggests.
#
# Step 2: Calculate the Test Statistic:
# Test Statistic (t): -38.0
#
# Step 3: Determine the Critical Value:
# Critical Value: 9.487729036781154
#
# Step 4: Make a Decision:
# Decision: Fail to reject the null hypothesis
#
# Step 5: Conclusion:
# Conclusion: There is not enough evidence to support the restaurant owners' claim that the weekly operating costs are higher than the model suggests.

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS ON A DATASET**

# %% [markdown]
# 1.	Data Cleaning and Preparation:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cardiotocographric.csv")

# %%
df.dropna(inplace=True) # Handling the missing values

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2105 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2105 non-null   float64
#  2   FM        2105 non-null   float64
#  3   UC        2105 non-null   float64
#  4   DL        2105 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2105 non-null   float64
#  8   MSTV      2105 non-null   float64
#  9   ALTV      2105 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 246.7 KB
# None

# %%
import scipy.stats as stats

# %%
pd.to_numeric(df['LB'], errors='coerce')  # If any numerical values are stored as strings, converting them to numeric
# Out:
# 0       120.000000
# 1       132.000000
# 2       133.000000
# 3       134.000000
# 4       131.948232
#            ...
# 2121    140.000000
# 2122    140.000000
# 2123    140.000000
# 2124    140.000000
# 2125    142.000000
# Name: LB, Length: 2105, dtype: float64

# %%
np.abs(stats.zscore(df.select_dtypes(include=['float64', 'int64'])))   # Step 3: Detecting the Outliers
# Out:
#             LB        AC         FM        UC        DL        DS       DP  \
# 0     1.184258  0.740798   0.146835  1.310156  0.565300  0.017731  0.20862
# 1     0.119246  0.735064   0.146835  0.594840  0.387636  0.017731  0.20862
# 2     0.030495  0.027778   0.146835  1.169977  0.427209  0.017731  0.20862
# 3     0.058256  0.148375   0.146835  1.001632  0.199733  0.017731  0.20862
# 4     0.123840  0.766312   0.146835  1.121506  0.565300  0.017731  0.20862
# ...        ...       ...        ...       ...       ...       ...      ...
# 2121  0.590762  0.740798  14.019859  0.907231  0.565300  0.017731  0.20862
# 2122  0.590762  0.561603   0.146835  0.773903  0.565300  0.017731  0.20862
# 2123  0.590762  0.513993   0.146835  0.739115  0.565300  0.017731  0.20862
# 2124  0.590762  0.583743   0.146835  0.514333  0.565300  0.017731  0.20862
# 2125  0.768264  0.367064   0.149600  1.101864  0.565300  0.017731  0.20862
#
# ...

# %%
threshold = 3

# %%
 (z_scores > threshold).any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121     True
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2105, dtype: bool

# %%
 df[~outliers]
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2120  140.000000  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# 2.	Statistical Summary:

# %%
df.describe()      ## statistical summary for each variable
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean    133.343598     0.003202     0.009963     0.004388     0.001892
# std      11.270154     0.004324     0.067870     0.003350     0.003348
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002554     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean      0.000003     0.000175    46.996929     1.361006    10.353647
# std       0.000142     0.000840    18.847737     1.173164    21.282102
# ...

# %%
print(summary)
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean    133.343598     0.003202     0.009963     0.004388     0.001892
# std      11.270154     0.004324     0.067870     0.003350     0.003348
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002554     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean      0.000003     0.000175    46.996929     1.361006    10.353647
# std       0.000142     0.000840    18.847737     1.173164    21.282102
# ...

# %%
## ●	Highlighting the interesting findings from this summary
print("Baseline Fetal Heart Rate (LB):")
print("Mean:", summary.loc['mean', 'LB'])
print("Median:", summary.loc['50%', 'LB'])
print("Standard Deviation:", summary.loc['std', 'LB'])
print("Interquartile Range (IQR):", summary.loc['75%', 'LB'] - summary.loc['25%', 'LB'])
# Out:
# Baseline Fetal Heart Rate (LB):
# Mean: 133.34359835512115
# Median: 133.0
# Standard Deviation: 11.270154059599935
# Interquartile Range (IQR): 14.0

# %% [markdown]
# 3.	Data Visualization:

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='LB', bins=20, kde=True)
plt.title('Distribution of Baseline Fetal Heart Rate (FHR)')
plt.xlabel('Baseline FHR')
plt.ylabel('Frequency')
plt.show()

# %%
# Use bar charts or pie charts
plt.figure(figsize=(5, 4))
sns.countplot(data=df, x='UC')
plt.title('Frequency of Uterine Contractions')
plt.xlabel('Uterine Contractions')
plt.ylabel('Count')
plt.show()

# %%
# Generate scatter plots
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x='LB', y='AC')
plt.title('Scatter Plot of Baseline FHR vs. Accelerations')
plt.xlabel('Baseline FHR')
plt.ylabel('Accelerations')
plt.show()

# %%
## Employ advanced visualization techniques like pair plots for deeper insights.
plt.figure(figsize=(12, 8))
sns.pairplot(df)
plt.suptitle('Pair Plot of Variables', y=1.02)
plt.show()

# %% [markdown]
# 4.	Pattern Recognition and Insights:

# %%
# Identify correlations between variables
correlation_matrix = df.corr()

# %%
# Plot correlation heatmap
plt.figure(figsize=(10,5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# 5.	Conclusion:

# %% [markdown]
# ### **Summary of Key Insights**

# %% [markdown]
# During the exploratory analysis of the cardiographic dataset, several key insights and patterns were uncovered.
#
# The distribution of baseline fetal heart rate (LB) exhibited a slightly right-skewed pattern, with a mean of X and a median of Y.
#
#  Accelerations (AC) showed a bimodal distribution, with the majority of observations clustered around X and Y.
#
#  Pairwise relationships between variables revealed moderate positive correlations between LB and AC, indicating a potential association between baseline fetal heart rate and accelerations.

# %% [markdown]
# #### **Implications for Decision-Making**

# %% [markdown]
#  The observed patterns in fetal heart rate and associated parameters could have implications for obstetricians and healthcare providers in monitoring fetal well-being during pregnancy.
#
#  Understanding the relationships between these variables may inform clinical decision-making and interventions aimed at optimizing maternal and fetal health outcomes.

# %% [markdown]
# **Recommendations for Further Analysis**

# %% [markdown]
# Further analyses could explore the temporal trends in fetal heart rate parameters over gestational age or investigate the impact of maternal factors on fetal heart rate variability.
#
# Additionally, incorporating additional clinical variables or demographic information into the analysis may provide a more comprehensive understanding of fetal health dynamics.
