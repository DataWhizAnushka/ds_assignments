# %% [markdown]
# <a href="https://colab.research.google.com/github/DataWhizAnushka/ds_assignments/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
# Yelp API - Fetch Village Restaurant details
def fetch_yelp_data(api_key, location, term):
    headers = {"Authorization": f"Bearer {api_key}"}
    url = f"https://api.yelp.com/v3/businesses/search"
    params = {"location": location, "term": term, "radius": 2000, "limit": 5}
    response = requests.get(url, headers=headers, params=params)
    return response.json()

# %%
# Google Maps API - Fetch busy times
def fetch_busy_times(api_key, place_id):
    url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&key={api_key}"
    response = requests.get(url)
    return response.json()

# %%
# OpenWeatherMap API - Fetch weather data
def fetch_weather_data(api_key, lat, lon):
    url = f"http://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"
    response = requests.get(url)
    return response.json()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
# Sample training data
# Features: [Temperature (°F), Busy Times (boolean), Rain (boolean)]
# Target: Menu prices
data = np.array([[50, 1, 1, 15], [60, 0, 0, 12], [40, 1, 1, 18]])
X = data[:, :3]
y = data[:, 3]

# %%
# Train model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Predict prices
def predict_price(temp_f, is_busy, is_raining):
    return model.predict([[temp_f, is_busy, is_raining]])[0]

# %%
# !pip install django
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 45.0 MB/s eta 0:00:00
# ...

# %%
from django.shortcuts import render

# %%
def display_results(request):
    yelp_data = fetch_yelp_data("your_yelp_api_key", "location", "Village Restaurant")
    busy_times = fetch_busy_times("your_gmaps_api_key", "place_id")
    weather_data = fetch_weather_data("your_openweather_api_key", lat, lon)

# %%
def display_results(request):
    yelp_data = fetch_yelp_data("your_yelp_api_key", "location", "Village Restaurant")
    busy_times = fetch_busy_times("your_gmaps_api_key", "place_id")
    weather_data = fetch_weather_data("your_openweather_api_key", lat, lon)
    # Example prediction
    temp_f = weather_data["main"]["temp"] - 273.15 * 9/5 + 32
    is_busy = 1 if busy_times["status"] == "busy" else 0
    is_raining = 1 if "rain" in weather_data else 0
    predicted_price = predict_price(temp_f, is_busy, is_raining)

    context = {
        "yelp_data": yelp_data,
        "busy_times": busy_times,
        "weather_data": weather_data,
        "predicted_price": predicted_price,
    }
    return render(request, "results.html", context)
