# %% [markdown]
# <a href="https://colab.research.google.com/github/DataWhizAnushka/ds_assignments/blob/main/Descriptive_Analytics_for_Numerical_Columns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Descriptive** **Analytics** **for** **Numerical** **Columns**

# %% [markdown]
# ●	Objective: To compute and analyze basic statistical measures for numerical columns in the dataset.

# %%
## 	Load the dataset into a data analysis tool or programming environment (e.g., Python with pandas library).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_data_with_discounts.csv")

# %%
df
# Out:
#                       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
## 	Identify numerical columns in the dataset.

# %%
numerical_columns = df.select_dtypes(include=['int']).columns
print(numerical_columns)
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value'], dtype='object')

# %%
## 	Calculate the mean, median, mode, and standard deviation for these columns.

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# ...

# %% [markdown]
# **Data** **Visualization**

# %% [markdown]
# ●	Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.

# %%
## 	Plot histograms for each numerical column.

# %%
df['Avg Price'].hist(bins=20)
# Out:
# <Axes: >

# %%
df['Total Sales Value'].hist(bins=20)
# Out:
# <Axes: >

# %%
df['Volume'].hist(bins=20)
# Out:
# <Axes: >

# %%
	## Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.

# %%
df.shape
# Out:
# (450, 13)

# %%
import seaborn as sns
sns.histplot(df['Volume'], kde=True)
sns.histplot(df['Total Sales Value'], kde=True)
sns.histplot(df['Avg Price'], kde=True)
plt.title('Histogram of Numerical Column')

plt.show()

# %%
from scipy.stats import zscore

# %%
z_scores = zscore(df['Volume'])
outliers = df[abs(z_scores) > 3]

# %%
z_scores = zscore(df['Total Sales Value'])
outliers = df[abs(z_scores) > 3]

# %%
z_scores = zscore(df['Avg Price'])
outliers = df[abs(z_scores) > 3]

# %%
 ## 	Create boxplots for numerical variables to identify outliers and the interquartile range.

# %%
sns.boxplot(x=df['Volume'])
plt.title('Boxplot of Numerical Column with Outliers')
plt.show()

# %%
cleaned_df = df[abs(z_scores) <= 3]

# %% [markdown]
# ●	**Bar** **Chart** **Analysis for Categorical Column**:**bold text**

# %%
## 	Identify categorical columns in the dataset.

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
print(categorical_columns)
# Out:
# Index([' ', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
## 	Create bar charts to visualize the frequency or count of each category.
	Analyze the distribution of categories and provide insights.

# %%
for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=column)
    plt.title(f'Frequency of Categories in {column}')
    plt.xticks(rotation=45)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# **Standardization of Numerical Variables**

# %% [markdown]
# ●	Objective: To scale numerical variables for uniformity, improving the dataset’s suitability for analytical models.

# %%
## 	Explain the concept of standardization (z-score normalization).

# %%
Standardization, also known as z-score normalization, is a data preprocessing technique used to transform numerical data into a standard format with a mean of 0 and a standard deviation of 1. This process helps in making data more interpretable and suitable for certain machine learning algorithms that assume normally distributed features.

# %%
## 	Standardize the numerical columns using the formula: z=x-mu/sigma

# %%
def standardize_column(column):
    mean = column.mean()
    std_dev = column.std()
    standardized_values = (column - mean) / std_dev
    return standardized_values

# %%
for column in df.select_dtypes(include='int'):
    df[column] = standardize_column(df[column])
    print(df)

# %%
## Show before and after comparisons of the data distributions.

# %%
import seaborn as sns

# %%
np.random.seed(0)
data = pd.DataFrame({
    'Feature A': np.random.normal(loc=50, scale=10, size=100),
    'Feature B': np.random.normal(loc=100, scale=20, size=100)})
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['Feature A'], kde=True, color='blue')
plt.title( ('Distribution of Feature A (Before Standardization'))

plt.subplot(1, 2, 2)
sns.histplot(data['Feature B'], kde=True, color='orange')
plt.title('Distribution of Feature B (after Standardization)')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Conversion of Categorical Data into Dummy Variables**

# %% [markdown]
# ●	Objective: To transform categorical variables into a format that can be provided to ML algorithms.

# %%
## 	Discuss the need for converting categorical data into dummy variables (one-hot encoding).

# %%
Converting categorical data into dummy variables, often referred to as one-hot encoding, is a common preprocessing step in machine learning and statistical modeling.
One hot encoding is a technique that we use to represent categorical variables as numerical values in a machine learning model.

# %%
	## Apply one-hot encoding to the categorical columns, creating binary (0 or 1) columns for each category.

# %%
data = {'category': ['brand']}
df = pd.DataFrame(data)

df_encoded = pd.get_dummies(df)

print("Original DataFrame:")
print(df)
print("\nDataFrame after one-hot encoding:")
print(df_encoded)
# Out:
# Original DataFrame:
#   category
# 0    brand
#
# DataFrame after one-hot encoding:
#    category_brand
# 0            True

# %%
## 	Display a portion of the transformed dataset.

# %%
print("Transformed DataFrame (portion):")
print(df_encoded.head())
# Out:
# Transformed DataFrame (portion):
#    category_brand
# 0            True

# %% [markdown]
# **●	Summarize the key findings from the descriptive analytics and data visualizations.**

# %% [markdown]
# To summarize key findings from descriptive analytics and data visualizations, we typically examine central tendencies, distributions, relationships between variables, and any notable patterns or outliers.

# %% [markdown]
# **●	Reflect on the importance of data preprocessing steps like standardization and one-hot encoding in data analysis and machine learning.**

# %% [markdown]
# data preprocessing steps like standardization and one-hot encoding are essential for ensuring that data is appropriately formatted and represented for analysis and modeling. They help to mitigate potential biases, improve algorithm performance, and ensure that the resulting models accurately capture the underlying patterns in the data. By performing these preprocessing steps thoughtfully, analysts and data scientists can enhance the quality and reliability of their analyses and machine learning models.

# %% [markdown]
# **Estimation And Confidence Intervals**

# %% [markdown]
# a. Build 99% Confidence Interval Using Sample Standard Deviation

# %%
import numpy as np
from scipy.stats import t

data = [1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29]
mean = np.mean(data)
std_dev = np.std(data, ddof=1)
n = len(data)
df = n - 1
confidence_level = 0.99

t_score = t.ppf((1 + confidence_level) / 2, df)
margin_of_error = t_score * (std_dev / np.sqrt(n))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Mean: {mean}")
print(f"Standard Deviation: {std_dev}")
print(f"Sample Size: {n}")
print(f"Degrees of Freedom: {df}")
print(f"t-score: {t_score}")
print(f"Margin of Error: {margin_of_error}")
print(f"99% Confidence Interval: ({lower_bound}, {upper_bound})")
# Out:
# Mean: 1.2386666666666666
# Standard Deviation: 0.19316412956959936
# Sample Size: 15
# Degrees of Freedom: 14
# t-score: 2.97684273411266
# Margin of Error: 0.1484693282152996
# 99% Confidence Interval: (1.090197338451367, 1.3871359948819662)

# %% [markdown]
# b. Build 99% Confidence Interval Using Known Population Standard Deviation

# %%
data = [1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29]
population_std_dev = 0.2
mean = np.mean(data)
n = len(data)
z_score = 2.576
margin_of_error = z_score * (population_std_dev / np.sqrt(n))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Mean: {mean}")
print(f"Sample Size: {n}")
print(f"Population Standard Deviation: {population_std_dev}")
print(f"Z-score: {z_score}")
print(f"Margin of Error: {margin_of_error}")
print(f"99% Confidence Interval: ({lower_bound}, {upper_bound})")
# Out:
# Mean: 1.2386666666666666
# Sample Size: 15
# Population Standard Deviation: 0.2
# Z-score: 2.576
# Margin of Error: 0.13302406799773742
# 99% Confidence Interval: (1.105642598668929, 1.371690734664404)
